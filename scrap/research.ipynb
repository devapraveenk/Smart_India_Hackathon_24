# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from fuzzywuzzy import process

# %%
from datagovindia import DataGovIndia
datagovin = DataGovIndia() # Specify API key if not set as an environment variable
# datagovin.sync_metadata()

# %%
search_data = datagovin.search('Onion')

# %%
search_data
# Out:
#                              resource_id  \
# 0   4319d311-87b0-410a-b0db-d9beff49c079
# 1   ce04d031-cd1f-4b92-a80d-70ef0e55e495
# 2   a699b6ee-7b92-46bb-95fb-56a9a47eb31a
# 3   6f682970-8df3-45eb-96b2-c9846c8383fa
# 4   35839665-e707-472a-b950-870e63535b53
# 5   cc89c3ae-4042-41d3-9b38-8fd1fef27f4d
# 6   c107432d-4dbb-4e0c-8caa-6ce011df6ce3
# 7   8ba0d98c-0fd0-49e2-b5f0-556c72b65d43
# 8   ab99a3a7-4b60-4dcc-94e8-d31e75edfd92
# 9   5fd06a97-41e9-44f3-9693-12ec07beafeb
# 10  2caf7e89-3c5c-4e0e-88cf-6670275486c9
# 11  01742262-931a-4bbf-97a5-6d5c3dc90181
# 12  a7856635-c351-4b20-8333-1c826da5249c
# 13  04ca8032-7a19-4e56-906e-e46c0cbef666
# 14  8a183dc4-fa1d-4322-aa82-f0981c9888b9
# 15  8bd88761-033f-4e74-8ce4-534460edf43a
# 16  f7001fa9-c6cf-425c-b0cf-5447debd00d3
# 17  052bf3bd-79ad-43e3-a700-2e4dad09efb0
# 18  8d779906-fe3b-4b1c-a081-6b0af25a8ab7
# 19  79471cc1-dbe9-4765-a5d6-671454deb8c1
# 20  d8d806a7-57ec-4e73-b481-9dd0ab8320a2
# 21  05feee95-39b7-4ff3-a823-0617a520d8d8
# ...

# %%
production = datagovin.get_data("05feee95-39b7-4ff3-a823-0617a520d8d8")

# %%
production
# Out:
#             months                         category    _2017    _2018  \
# 0          January       Retail Prices (Rs. Per kg)    14.84    42.69
# 1         February       Retail Prices (Rs. Per kg)    14.61    35.12
# 2            March       Retail Prices (Rs. Per kg)    14.52    26.18
# 3            April       Retail Prices (Rs. Per kg)    14.36    19.28
# 4              May       Retail Prices (Rs. Per kg)    14.07    16.72
# 5             June       Retail Prices (Rs. Per kg)    14.56    17.78
# 6             July       Retail Prices (Rs. Per kg)    15.04    21.02
# 7           August       Retail Prices (Rs. Per kg)    26.02    21.60
# 8        September       Retail Prices (Rs. Per kg)    26.58    20.60
# 9          October       Retail Prices (Rs. Per kg)    30.11    21.41
# 10        November       Retail Prices (Rs. Per kg)    39.07    22.02
# 11        December       Retail Prices (Rs. Per kg)    43.44    19.36
# ...

# %%
production1 = datagovin.get_data("cc89c3ae-4042-41d3-9b38-8fd1fef27f4d")

# %%
production1
# Out:
#             states  current_week_09_08_2016  previous_week_02_08_2016  \
# 0            Delhi                      800                       775
# 1          Haryana                     1170                      1215
# 2           Punjab                     1200                      1267
# 3    Uttar Pradesh                     1313                      1313
# 4          Gujarat                     1250                      1294
# 5   Madhya Pradesh                      717                       775
# 6      Maharashtra                     1217                      1282
# 7        Rajasthan                     1133                      1050
# 8            Bihar                     1133                      1133
# 9      West Bengal                     1300                      1450
# 10       Telangana                     1200                      1200
# 11      Seemandhra                     1333                      1333
# ...
